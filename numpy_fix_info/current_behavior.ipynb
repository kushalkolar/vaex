# %%
import vaex
import numpy as np

# %% [markdown]
# just make some dataframe

# %%
df = vaex.from_dict({'A':[1,2,3],'B':['a','b','c']})

# %%
df
# Out:
#   #    A  B
#   0    1  a
#   1    2  b
#   2    3  c

# %% [markdown]
# ### Create an arrays of numpy arrays that can be set as a column.
#
# The individual arrays are of different lengths so that they don't get vstacked automatically.
# This is to simulate the result of pandas.DataFrame.values

# %%
a = np.array([np.array(range(3))]*2 + [np.array(range(4))])
a
# Out:
# array([array([0, 1, 2]), array([0, 1, 2]), array([0, 1, 2, 3])],
#       dtype=object)

# %% [markdown]
# ### Setting the new column from the arrays raises this exception

# %%
df['arrays'] = a
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-fa16d79e2fb3> in <module>
# ----> 1 df['arrays'] = a
#
# ~/python-virtual-environments/mesmerize_vaex/lib/python3.6/site-packages/vaex/dataframe.py in __setitem__(self, name, value)
#    4251                 value = value.expression
#    4252             if isinstance(value, (np.ndarray, Column)):
# -> 4253                 self.add_column(name, value)
#    4254             else:
#    4255                 self.add_virtual_column(name, value)
#
# ~/python-virtual-environments/mesmerize_vaex/lib/python3.6/site-packages/vaex/dataframe.py in add_column(self, name, data, dtype)
#    5405         #     self._length_original = len(data)
#    5406         #     self._index_end = self._length_unfiltered
# -> 5407         super(DataFrameArrays, self).add_column(name, data, dtype=dtype)
# ...

# %%
df.columns
# Out:
# OrderedDict([('A', array([1, 2, 3])),
#              ('B', array(['a', 'b', 'c'], dtype='<U1')),
#              ('arrays',
#               array([array([0, 1, 2]), array([0, 1, 2]), array([0, 1, 2, 3])],
#                     dtype=object))])

# %% [markdown]
# But the new columns is there!

# %%
df['arrays']
# Out:
# Expression = arrays
# Length: 3 dtype: object (column)
# --------------------------------
# 0    [0 1 2]
# 1    [0 1 2]
# 2  [0 1 2 3]

# %% [markdown]
# And the data in the new column are also properly there!

# %%
df['arrays'].dtype
# Out:
# dtype('O')

# %% [markdown]
# ### Exception raised when you try to print the whole dataframe

# %%
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/python-virtual-environments/mesmerize_vaex/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# ~/python-virtual-environments/mesmerize_vaex/lib/python3.6/site-packages/vaex/dataframe.py in _repr_mimebundle_(self, include, exclude, **kwargs)
#    3451         # TODO: optimize, since we use the same data in both versions
#    3452         # TODO: include latex version
# -> 3453         return {'text/html':self._head_and_tail_table(format='html'), 'text/plain': self._head_and_tail_table(format='plain')}
#    3454
#    3455     def _repr_html_(self):
#
# ...
